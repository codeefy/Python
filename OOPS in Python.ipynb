# %% [markdown]
#   **Syntax to creat an object**

# %%
#objectname=classname()

# %%
#objectliteral
L=[1,2,3,4] # this is inbuilt object of list class

# %%
L=list() # this is creating object using constructor
L
# Out:
# []

# %%
S=str() # this is creating object of string class using constructor
S
# Out:
# ''

# %% [markdown]
# **Creating a class ATM**

# %%
#pascal case 
# class StudentDetails: two words start with capital letter
class Atm:
    #constructor : it is a special function which is called at the time of object creation
    def __init__(self): 
        self.pin=''
        self.balance=0
       # print("execute")
        self.menu()
# There are two types of classes in python inbuilt like list , tuple, dict 
# and user defied classes this is user defined classes . 
    def menu(self):
        user_input=input("""HI how can i help you 
                         1. Press 1 to create pin
                         2. Press 2 to change Pin 
                         3. Press 3 to check Balance
                         4. Press 4 to withdraw
                         5 anything else to exit  """)
        if user_input=='1':
            #create Pin 
            self.Create_pin()
        elif user_input=='2':
            #change pin
            self.change_pin()
        elif user_input=='3':
            #check balance 
            self.check_balance()
        elif user_input=='4':
            #withdraw
            self.withdraw()
            
        else:
            exit()

    def Create_pin(self):
        user_pin=input("Enter your pin ")
        self.pin=user_pin

        user_balance=int(input("enter Your balance "))
        self.balance=user_balance
        print("your pin is created successfully")
        self.menu()
    
    def change_pin(self):
        old_pin=input("enter old pin")

        if old_pin==self.pin:
            #let him change the pin 
            new_pin=input("enter New pin")
            self.pin=new_pin
            print("pin change succesfully")
            self.menu()
        else:
            print("Permissioon Denied")
            self.menu()
    
    def check_balance(self):
        user_pin=input("enter your Pin")
        if user_pin==self.pin:
            print("your balance is ",self.balance)
        else:
            print("permission denied")
            self.menu()
    
    def withdraw(self):
        user_pin=input("enter your Pin")
        if user_pin==self.pin:
            amount=int(input("enter amount to withdraw "))
            if amount<=self.balance:
                self.balance=self.balance - amount
                print("please collect your cash")
                print("your remaining balance is ",self.balance)
                self.menu()
            else:
                print("insufficient balance")
                self.menu()
        else:
            print("permission denied")
            self.menu()

# %%
obj=Atm() #objectname=classname()
# Out:
# your pin is created successfully
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %%
print(type(obj))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 print(type(obj))
#
# NameError: name 'obj' is not defined

# %%
L=[1,2,3]
len(L) # it is a function because it is not associated with object L because len() is a built in function in python
L.append(4) # it is a method because it is associated with object L because append() is a method of list class
# Out:
# [1, 2, 3, 4]

# %%
s=int(input("enter a number "))
print(s)
# Out:
# 1

# %% [markdown]
# **Fraction**

# %%
class fraction:

    #parameterized constructor 
    def __init__(self,x,y):
        self.num=x
        self.den=y
    def __str__(self):
        return '{}/{}'.format(self.num,self.den)
    
    def __add__(self,other):
        new_num=self.num*other.den+other.num*self.den # basic fraction addition cross multiplication 
        new_den=self.den*other.den
        return '{}/{}'.format(new_num,new_den)
    def __sub__(self,other):
        new_num=self.num*other.den-other.num*self.den 
        new_den=self.den*other.den
        return '{}/{}'.format(new_num,new_den)
    def __mul__(self,other):
        new_num=self.num*other.num
        new_den=self.den*other.den
        return '{}/{}'.format(new_num,new_den)
    def __truediv__(self,other):
        new_num=self.num*other.den
        new_den=self.den*other.num
        return '{}/{}'.format(new_num,new_den)
    def convert_to_decimal(self):
        return self.num/self.den

# %%
fr1=fraction(3,4)
fr2=fraction(1,2)

# %%
fr1.convert_to_decimal()
# Out:
# 0.75

# %%
#print(fr1,fr2)
#print(fr1+fr2) # it will give error because we have not defined how to add two fraction objects 
print(fr1+fr2) # now it will add up  becaaues we have defined the how we add two fraction object 
print(fr1-fr2)
print(fr1*fr2)
print(fr1/fr2)
# Out:
# 10/8
# 2/8
# 3/8
# 6/4

# %% [markdown]
# ##`Q-1:` Rectangle Class
# 1. Write a Rectangle class in Python language, allowing you to build a rectangle with length and width attributes.
# 2. Create a Perimeter() method to calculate the perimeter of the rectangle and a Area() method to calculate the area of ​​the rectangle.
# 3. Create a method display() that display the length, width, perimeter and area of an object created using an instantiation on rectangle class.

# %%
class Rectangle:
    #1. Write a Rectangle class in Python language, allowing you to build a rectangle with length and width attributes.
    def __init__(self,length,width):
        self.length=length
        self.width=width
    #2. Create a Perimeter() method to calculate the perimeter of the rectangle and a Area() method to calculate the area of ​​the rectangle.
    def Perimeter(self): # self here becomes the object created using instantiation on rectangle class
        return 2*(self.length + self.width)
    def Area(self): 
        return self.length * self.width
    #3. Create a method display() that display the length, width, perimeter and area of an object created using an instantiation on rectangle class.
    def display(self): 
        print("Length:",self.length)
        print("Width:",self.width)
        print("Perimeter:",self.Perimeter())
        print("Area:",self.Area())

# %%
perimeter=Rectangle(3,4)
perimeter.display()
# Out:
# Length: 3
# Width: 4
# Perimeter: 14
# Area: 12

# %% [markdown]
# ##`Q-2: Bank Class`
#
# 1. Create a Python class called `BankAccount` which represents a bank account, having as attributes: `accountNumber` (numeric type), `name` (name of the account owner as string type), `balance`.
# 2. Create a constructor with parameters: `accountNumber, name, balance`.
# 3. Create a `Deposit()` method which manages the deposit actions.
# 4. Create a `Withdrawal()` method  which manages withdrawals actions.
# 5. Create an `bankFees()` method to apply the bank fees with a percentage of 5% of the balance account.
# 6. Create a `display()` method to display account details.
# Give the complete code for the  BankAccount class.
