# %% [markdown]
#   **Syntax to creat an object**

# %%
#objectname=classname()

# %%
#objectliteral
L=[1,2,3,4] # this is inbuilt object of list class

# %%
L=list() # this is creating object using constructor
L
# Out:
# []

# %%
S=str() # this is creating object of string class using constructor
S
# Out:
# ''

# %% [markdown]
# **Creating a class ATM**

# %%
#pascal case 
# class StudentDetails: two words start with capital letter
class Atm:
    #constructor : it is a special function which is called at the time of object creation
    def __init__(self): 
        self.pin=''
        self.balance=0
       # print("execute")
        self.menu()
# There are two types of classes in python inbuilt like list , tuple, dict 
# and user defied classes this is user defined classes . 
    def menu (self):
        user_input=input("""HI how can i help you 
                         1. Press 1 to create pin
                         2. Press 2 to change Pin 
                         3. Press 3 to check Balance
                         4. Press 4 to withdraw
                         5 anything else to exit  """)
        if user_input=='1':
            #create Pin 
            self.Create_pin()
        elif user_input=='2':
            #change pin
            pass
        elif user_input=='3':
            #check balance 
            pass
        elif user_input=='4':
            #withdraw
            pass
        else:
            exit()

    def Create_pin(self):
        user_pin=input("Enter your pin ")
        self.pin=user_pin

        user_balance=int(input("enter Your balance "))
        self.balance=user_balance
        print("your pin is created successfully")

# %%
obj=Atm() #objectname=classname()
# Out:
# your pin is created successfully

# %%
print(type(obj))
# Out:
# <class '__main__.Atm'>

# %%
obj.
